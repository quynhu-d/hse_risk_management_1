# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('whitegrid')
import matplotlib.pyplot as plt
import scipy.stats as stats
import statsmodels.api as sm
import pylab

from tqdm.auto import tqdm, trange

# %% [markdown]
# # Данные (симуляции)

# %%
data = np.load('../results/simulations/mean_portfolio_sim.npy')

# %%
data.shape  # n_portfolio_type x n_sim x n_days
# Out:
# (3, 100, 10)

# %%
var_data = pd.DataFrame([pd.DataFrame(data[i].T).pct_change().dropna().iloc[0] for i in range(3)]).T  # one day
var_data.columns = ['currencies', 'stocks', 'bonds']
var_data.head(2)  # returns
# Out:
#    currencies    stocks     bonds
# 0   -0.002022  0.005985 -0.003399
# 1    0.002412 -0.006234 -0.000389

# %%
var_data['portfolio'] = var_data['bonds'] * 50/260 + var_data['stocks'] * 10/260 + \
var_data['currencies'] * 200/260

# %%
var_data.head(2)
# Out:
#    currencies    stocks     bonds  portfolio
# 0   -0.002022  0.005985 -0.003399  -0.001979
# 1    0.002412 -0.006234 -0.000389   0.001541

# %%
var_data.shape  # n_sim x n_portfolio_type
# Out:
# (100, 4)

# %%
plt.figure(figsize=(6,4))
sns.histplot(var_data, x='portfolio', bins=100, color='#104294', stat='density', kde=True);

# %% [markdown]
# # VaR-99, ES-97.5

# %% [markdown]
# ### Параметрический подход

# %%
from var_es import Parametric_VE

# %%
ret = var_data['portfolio']
param_ve = Parametric_VE(ret)

param_ve.get_var_es()

# %%
param_ve.plot_dist()

# %%
param_ve.print_res()
# Out:
# 1-day VaR 99%: -0.012
# 1-day ES 97.5%: -0.013
# 10-day VaR 99%: -0.037
# 10-day ES 97.5%: -0.040

# %% [markdown]
# ### Исторический подход

# %%
from var_es import Historical_VE
hist_ve = Historical_VE(ret)

# %%
hist_ve.get_var_es()
hist_ve.print_res()
hist_ve.plot_dist()
# Out:
# 1-day VaR 99%: -0.012
# 1-day ES 97.5%: -0.012
# 10-day VaR 99%: -0.039
# 10-day ES 97.5%: -0.036

# %% [markdown]
# ### Bootstrapping

# %%
from var_es import Bootstrap_VE
boot_ve = Bootstrap_VE(ret)

# %%
boot_ve.get_var_es()
boot_ve.print_res()
# Out:
# ...
#   0%|          | 0/10000 [00:00<?, ?it/s]
# 1-day VaR 99%: -0.011
# 1-day ES 97.5%: -0.012
# 10-day VaR 99%: -0.035
# 10-day ES 97.5%: -0.036

# %%
from tabulate import tabulate

print(
    tabulate(
        [
            ['Parametric, 1d', param_ve.var99_1d, param_ve.cvar975_1d], 
            ['Historical, 1d', hist_ve.var99_1d, hist_ve.cvar975_1d],
            ['Parametric, 10d', param_ve.var99_10d, param_ve.cvar975_10d], 
            ['Historical, 10d', hist_ve.var99_10d, hist_ve.cvar975_10d],
            ['Bootstrapping, 1d', boot_ve.var99_1d, boot_ve.cvar975_1d], 
            ['Bootstrapping, 10d', boot_ve.var99_10d, boot_ve.cvar975_10d]
        ],
        headers=['Approach', 'Value at Risk 99%', 'Conditional Value at Risk (ES) 97.5%'],
        tablefmt = 'fancy_grid',
        stralign = 'center',
        numalign= 'center',
        floatfmt=".4f"
    )
)
# Out:
# ╒════════════════════╤═════════════════════╤════════════════════════════════════════╕
# │      Approach      │  Value at Risk 99%  │  Conditional Value at Risk (ES) 97.5%  │
# ╞════════════════════╪═════════════════════╪════════════════════════════════════════╡
# │   Parametric, 1d   │       -0.0119       │                -0.0126                 │
# ├────────────────────┼─────────────────────┼────────────────────────────────────────┤
# │   Historical, 1d   │       -0.0122       │                -0.0115                 │
# ├────────────────────┼─────────────────────┼────────────────────────────────────────┤
# │  Parametric, 10d   │       -0.0375       │                -0.0397                 │
# ├────────────────────┼─────────────────────┼────────────────────────────────────────┤
# │  Historical, 10d   │       -0.0385       │                -0.0364                 │
# ├────────────────────┼─────────────────────┼────────────────────────────────────────┤
# ...

# %% [markdown]
# # Backtesting

# %%
# !pip install var
# !pip install arch

# %%
data = np.load('../results/simulations/mean_2022_portfolio_sim.npy')

# %%
bt_data = pd.DataFrame(data[:,0].T).pct_change()
bt_data.index = pd.date_range(start = '2022-01-01', end = '2022-12-31', freq = 'd')
bt_data.columns = ['currencies', 'stocks', 'bonds']
bt_data['portfolio'] = bt_data['bonds'] * 50/260 + bt_data['stocks'] * 10/260 + \
bt_data['currencies'] * 200/260

# %%
from var import VaR, load_data

var = {}
bth = {}
for pf in bt_data.columns:
    var[pf] = VaR(pd.DataFrame(bt_data.dropna()[pf]), weights=np.array([1]))
    var[pf].monte_carlo()
    try:
        bth[pf] = var[pf].backtest(method='h')
        var[pf].evaluate(bth[pf], )
    except:
        pass
# Out:
# ...
# Backtest: Historic Method: 100%|████████████████████████████████████████████████████| 114/114 [00:00<00:00, 690.81it/s]

# %%
var['portfolio'].var_plot(bth['portfolio'])

# %%
var['bonds'].var_plot(bth['bonds'])

# %%
var['stocks'].var_plot(bth['stocks'])

# %%
var['currencies'].var_plot(bth['currencies'])

# %%
var['portfolio'].cvar_plot(bth['portfolio'])

# %%
var['bonds'].cvar_plot(bth['bonds'])

# %%
var['stocks'].cvar_plot(bth['stocks'])

# %%
var['currencies'].cvar_plot(bth['currencies'])

# %% [markdown]
# # Real data

# %%
real_data = pd.read_excel('../data/Final_data.xlsx')
real_data = real_data.fillna(method='ffill').fillna(method='bfill')
real_data = real_data.drop(real_data.tail(29).index)
real_data.set_index('Date', inplace=True)
# real_data.drop(columns='Date').pct_change().dropna().describe()

# %%
currencies = ['Курс евро', 'Курс доллара']
stocks = [
    'Аэрофлот', 'Газпром', 'ГМК Норникель', 'Лукойл', 'МТС', 
    'ПИК', 'Роснефть', 'Сбербанк', 'Татнефть', 'Яндекс'
]
bonds = ['ОФЗ_26207', 'ОФЗ_26215', 'ОФЗ_26218', 'ОФЗ_26219', 'ОФЗ_26222']
# var_data = pd.DataFrame(index=real_data.Date)
var_data = pd.DataFrame()
var_data['currencies'] = real_data.pct_change().dropna()[currencies].mean(axis=1)
var_data['stocks'] = real_data.pct_change().dropna()[stocks].mean(axis=1)
var_data['bonds'] = real_data.pct_change().dropna()[bonds].mean(axis=1)
# var_data = var_data.pct_change().dropna()
var_data.index = real_data.index[1:]
var_data['portfolio'] = var_data['bonds'] * 50/260 + var_data['stocks'] * 10/260 + \
var_data['currencies'] * 200/260
var_data.tail(2)  # returns
# Out:
#             currencies  stocks     bonds  portfolio
# Date
# 2022-12-01   -0.004252     0.0 -0.000576  -0.003382
# 2022-12-02    0.008363     0.0  0.000238   0.006479

# %%
## parametric
param_ve = Parametric_VE(var_data.portfolio)
param_ve.get_var_es()
param_ve.plot_dist()

# %%
## historical
hist_ve = Historical_VE(var_data.portfolio)
hist_ve.get_var_es()
hist_ve.plot_dist()

# %%
## bootstrap
boot_ve = Bootstrap_VE(var_data.portfolio)
boot_ve.get_var_es()
boot_ve.plot_dist()
# Out:
# ...
#   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
from tabulate import tabulate

print(
    tabulate(
        [
            ['Parametric, 1d', param_ve.var99_1d, param_ve.cvar975_1d], 
            ['Historical, 1d', hist_ve.var99_1d, hist_ve.cvar975_1d],
            ['Parametric, 10d', param_ve.var99_10d, param_ve.cvar975_10d], 
            ['Historical, 10d', hist_ve.var99_10d, hist_ve.cvar975_10d],
            ['Bootstrapping, 1d', boot_ve.var99_1d, boot_ve.cvar975_1d], 
            ['Bootstrapping, 10d', boot_ve.var99_10d, boot_ve.cvar975_10d]
        ],
        headers=['Approach', 'Value at Risk 99%', 'Conditional Value at Risk (ES) 97.5%'],
        tablefmt = 'fancy_grid',
        stralign = 'center',
        numalign= 'center',
        floatfmt=".4f"
    )
)
# Out:
# ╒════════════════════╤═════════════════════╤════════════════════════════════════════╕
# │      Approach      │  Value at Risk 99%  │  Conditional Value at Risk (ES) 97.5%  │
# ╞════════════════════╪═════════════════════╪════════════════════════════════════════╡
# │   Parametric, 1d   │       -0.0194       │                -0.0260                 │
# ├────────────────────┼─────────────────────┼────────────────────────────────────────┤
# │   Historical, 1d   │       -0.0256       │                -0.0254                 │
# ├────────────────────┼─────────────────────┼────────────────────────────────────────┤
# │  Parametric, 10d   │       -0.0614       │                -0.0823                 │
# ├────────────────────┼─────────────────────┼────────────────────────────────────────┤
# │  Historical, 10d   │       -0.0810       │                -0.0802                 │
# ├────────────────────┼─────────────────────┼────────────────────────────────────────┤
# ...

# %%
## backtesting
var = VaR(pd.DataFrame(var_data.portfolio), weights=np.array([1]))
try:
    bth = var.backtest(method='h')
    var.evaluate(bth)
except:
    pass
# Out:
# Backtest: Historic Method: 100%|██████████████████████████████████████████████████| 2642/2642 [00:02<00:00, 978.92it/s]

# %%
var.var_plot(bth)

# %%
var.cvar_plot(bth)
